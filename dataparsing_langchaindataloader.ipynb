# %% [markdown]
# ##Indexing differnt format files

# %%
from langchain_community.document_loaders import (
TextLoader,
PyPDFLoader,
CSVLoader,
Docx2txtLoader,
JSONLoader,
UnstructuredWordDocumentLoader,
UnstructuredHTMLLoader,
UnstructuredMarkdownLoader
)

# %% [markdown]
# # #PDF Uploader

# %%
my_pdf = PyPDFLoader("E:\\AIWorkspace\\ai-data-engg-ramesh-learnings\\sample_document.pdf")

# %%
my_pdf=my_pdf.load()

# %%
my_pdf[0].metadata
# Out:
# {'producer': 'ReportLab PDF Library - (opensource)',
#  'creator': '(unspecified)',
#  'creationdate': '2026-07-04T16:55:50+00:00',
#  'author': '(anonymous)',
#  'keywords': '',
#  'moddate': '2026-07-04T16:55:50+00:00',
#  'subject': '(unspecified)',
#  'title': '(anonymous)',
#  'trapped': '/False',
#  'source': 'E:\\AIWorkspace\\ai-data-engg-ramesh-learnings\\sample_document.pdf',
#  'total_pages': 1,
#  'page': 0,
#  'page_label': '1'}

# %%
print(my_pdf[0].page_content)
# Out:
# LangChain PDF Loader Sample
# This PDF is used to demonstrate PyPDFLoader in LangChain.
# Refund Policy
# Refunds are allowed within 7 days of purchase if the product is unused and the invoice is available.
# Support SLA
# Priority 1 tickets should receive a first response within 2 hours.
# Policy
# Owner
# Update Frequency
# Refund Policy
# Support
# Quarterly
# Leave Policy
# HR
# Yearly

# %% [markdown]
# # TXT Loader

# %%
Text_file=TextLoader("E:\\AIWorkspace\\ai-data-engg-ramesh-learnings\\sampletext.txt")

# %%
Text_file=Text_file.load()

# %%
Text_file[0].metadata
# Out:
# {'source': 'E:\\AIWorkspace\\ai-data-engg-ramesh-learnings\\sampletext.txt'}

# %%
print(Text_file[0].page_content)
# Out:
# LangChain Starter Parser Sample
#
# This text file is used to demonstrate TextLoader.
#
# RAG stands for Retrieval-Augmented Generation. In a RAG pipeline, documents are parsed, split into chunks, converted into embeddings, stored in a vector database, and retrieved at query time.
#
# Refund Policy Example:
# Refunds are allowed within 7 days of purchase if the product is unused and the invoice is available.

# %% [markdown]
# # CSV Loader

# %%
csv_loader = CSVLoader("E:\\AIWorkspace\\ai-data-engg-ramesh-learnings\\sample_data.csv")

# %%
csv_loader=csv_loader.load()

# %% [markdown]
# # JSON Loader

# %%
json_loader = JSONLoader("E:\\AIWorkspace\\ai-data-engg-ramesh-learnings\\sample_data.json",
jq_schema=".[]",
text_content=False)
#The JSON loader was configured with:

#jq_schema=".items[]"
#But your JSON file is a top-level array, not an object with an items field.

# %%
json_loader=json_loader.load()

# %%
print(json_loader[0].page_content)
# Out:
# {"id": "doc-001", "title": "Refund Policy", "content": "Refunds are allowed within 7 days of purchase if the product is unused.", "metadata": {"department": "Support", "source": "policy_portal"}}

# %% [markdown]
# ##html Loader

# %%
html_loader=UnstructuredHTMLLoader("E:\\AIWorkspace\\ai-data-engg-ramesh-learnings\\sample_page.html")

# %%
html_loader = html_loader.load()

# %%
print(html_loader[0].page_content)
# Out:
# Company Knowledge Base
#
# Refund Policy
#
# Refunds are allowed within 7 days of purchase if the product is unused and the invoice is available.
#
# Support SLA
#
# Priority 1 tickets should receive a first response within 2 hours.
#
# Channel: Email
#
# Channel: Chat
#
# Channel: Phone

# %% [markdown]
# ##DOC Loader

# %%
Doc_loader=UnstructuredWordDocumentLoader("E:\\AIWorkspace\\ai-data-engg-ramesh-learnings\\sample_document.docx")

# %%
Doc_loader = Doc_loader.load()

# %%
print(Doc_loader[0].page_content)
# Out:
# LangChain DOCX Loader Sample
#
# This document is used to demonstrate Docx2txtLoader in LangChain.
#
# Refund Policy
#
# Refunds are allowed within 7 days of purchase if the product is unused and the invoice is available.
#
# Leave Policy
#
# Employees receive 18 paid leaves per year and 8 sick leaves per year.
#
# Simple Table
#
# Policy Owner Update Frequency Refund Policy Support Quarterly Leave Policy HR Yearly

# %% [markdown]
# #markdone Loader

# %%
json_loader = JSONLoader(
    "E:\\AIWorkspace\\ai-data-engg-ramesh-learnings\\sample_data.json",
    jq_schema=".[]",
    text_content=False
)
json_loader = json_loader.load()
